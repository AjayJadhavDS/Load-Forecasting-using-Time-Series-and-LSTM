# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
df = pd.read_csv('C:/Users/ajadhav/Downloads/LoadForecasting/saudi-arabia-electricity-load-monthly-by-region.csv',sep=';')
df = df[['Date','Eastern region - Minimum (GW)']]
df.columns = ['Date','Load']

# %%
df.shape
# Out:
# (108, 2)

# %%
df.Date = pd.to_datetime(df.Date)

# %%
df = df.sort_values(by='Date')

# %%
df = df.set_index('Date')

# %% [markdown]
# # 1. Time Series

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(df)
plt.xlabel('Date')
plt.ylabel('Load')
# Out:
# Text(0,0.5,'Load')

# %%
import statsmodels.api as sm

decomposition = sm.tsa.seasonal_decompose(df, model='additive')
fig = decomposition.plot()
plt.show()

# %%
import itertools
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %%
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(df,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            results = mod.fit()
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:796.2669552404398
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:622.1671842732221
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:341.30037364814785
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:310.9378814239907
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:337.45339152878864
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:317.9084833909811
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:313.6999362346908
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:312.8984061993111
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:653.4074088708687
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:511.1364529552255
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:295.0606415567016
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:264.7663938922825
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:297.2789805299917
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:265.1802722435875
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:268.0663124170936
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:263.78266943419237
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:342.77371995323415
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:291.54246172973876
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:274.3617529589668
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:202.33390287840794
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:262.9706715291836
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:226.23304323278535
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:210.39968808759895
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:203.4429390547884
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:319.5374307402639
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:283.00924264367393
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:272.24155502338635
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:200.85008224320862
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:264.97033348347173
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:224.292575420242
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:212.23117949886768
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:202.34401159345856
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:346.8899174275925
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:295.5154169807335
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:265.5045574911427
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:203.67409108679993
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:263.5685827631014
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:224.40479112165153
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:207.64763098100616
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:204.42611881048288
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:323.35705077047993
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:286.74765324446895
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:265.72097234707184
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:203.06368241694508
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:265.5649145845642
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:224.6556638385595
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:209.63762300932578
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:204.2865972671728
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:315.94436187581067
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:282.19210956300964
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:274.454523569064
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:202.83541398019238
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:263.2280613047861
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:226.54955367315972
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:210.74667769767063
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:204.3165537333942
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:315.7472705668927
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:282.2390012123331
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:266.2748290301375
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:197.94969654845366
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:265.22807725008744
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:220.9950724879108
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:208.94099144389855
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:200.2139292071538
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %%
#ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:197.94969654845366

mod = sm.tsa.statespace.SARIMAX(df,
                                order=(1, 1, 1),
                                seasonal_order=(0, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
# Out:
# C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %%
print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5544      0.241      2.302      0.021       0.082       1.026
# ma.L1         -0.8106      0.192     -4.230      0.000      -1.186      -0.435
# ma.S.L12      -1.0001    717.064     -0.001      0.999   -1406.419    1404.419
# sigma2         0.4914    352.422      0.001      0.999    -690.242     691.225
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()

# %%
pred = results.get_prediction(start=pd.to_datetime('2017-01-01'), dynamic=False)
pred_ci = pred.conf_int()

# %%
pred_ci.head()
# Out:
#             lower Load  upper Load
# 2017-01-01    8.653590   11.591528
# 2017-02-01    8.683976   11.608356
# 2017-03-01    8.203705   11.124752
# 2017-04-01    8.670883   11.589763
# 2017-05-01   10.724034   13.641498

# %%
ax = df['2014':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Furniture Sales')
plt.legend()
plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = df['2017-01-01':]
mse = ((y_forecasted.values - y_truth.values) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 8.87

# %% [markdown]
# # 2. Deep Learning LSTM model

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(df)

# %%
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 72 36

# %%
import numpy

def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM


# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100,validation_data=[testX,testY] ,batch_size=1, verbose=1)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\ajadhav\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 70 samples, validate on 34 samples
# Epoch 1/100
# 70/70 [==============================] - 1s 19ms/step - loss: 0.0755 - val_loss: 0.1612
# Epoch 2/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0352 - val_loss: 0.0905
# Epoch 3/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0204 - val_loss: 0.0607
# Epoch 4/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0167 - val_loss: 0.0457
# Epoch 5/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0160 - val_loss: 0.0404
# Epoch 6/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0155 - val_loss: 0.0372
# Epoch 7/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0150 - val_loss: 0.0372
# Epoch 8/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0144 - val_loss: 0.0359
# Epoch 9/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0138 - val_loss: 0.0320
# Epoch 10/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0132 - val_loss: 0.0308
# Epoch 11/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0129 - val_loss: 0.0282
# Epoch 12/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0123 - val_loss: 0.0274
# Epoch 13/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0120 - val_loss: 0.0275
# Epoch 14/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0117 - val_loss: 0.0246
# Epoch 15/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0112 - val_loss: 0.0238
# Epoch 16/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0110 - val_loss: 0.0219
# Epoch 17/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0108 - val_loss: 0.0223
# Epoch 18/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0105 - val_loss: 0.0196
# Epoch 19/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0102 - val_loss: 0.0208
# Epoch 20/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0101 - val_loss: 0.0187
# Epoch 21/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0100 - val_loss: 0.0186
# Epoch 22/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0099 - val_loss: 0.0178
# Epoch 23/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0097 - val_loss: 0.0174
# Epoch 24/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0096 - val_loss: 0.0163
# Epoch 25/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0096 - val_loss: 0.0155
# Epoch 26/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0095 - val_loss: 0.0159
# Epoch 27/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0096 - val_loss: 0.0157
# Epoch 28/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0150
# Epoch 29/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0095 - val_loss: 0.0145
# Epoch 30/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0159
# Epoch 31/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0148
# Epoch 32/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0093 - val_loss: 0.0146
# Epoch 33/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0147
# Epoch 34/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0095 - val_loss: 0.0155
# Epoch 35/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0149
# Epoch 36/100
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0148
# Epoch 37/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0147
# Epoch 38/100
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0151
# Epoch 39/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0145
# Epoch 40/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0138
# Epoch 41/100
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0094 - val_loss: 0.0142
# Epoch 42/100
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0142
# Epoch 43/100
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0141
# Epoch 44/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0141
# Epoch 45/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0137
# Epoch 46/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0137
# Epoch 47/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0096 - val_loss: 0.0132
# Epoch 48/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0135
# Epoch 49/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0149
# Epoch 50/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0139
# Epoch 51/100
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0138
# Epoch 52/100
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0095 - val_loss: 0.0150
# Epoch 53/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0144
# Epoch 54/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0095 - val_loss: 0.0145
# Epoch 55/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0141
# Epoch 56/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0141
# Epoch 57/100
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0092 - val_loss: 0.0145
# Epoch 58/100
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0094 - val_loss: 0.0148
# Epoch 59/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0142
# Epoch 60/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0147
# Epoch 61/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0142
# Epoch 62/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0147
# Epoch 63/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0143
# Epoch 64/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0092 - val_loss: 0.0140
# Epoch 65/100
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0133
# Epoch 66/100
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0094 - val_loss: 0.0136
# Epoch 67/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0139
# Epoch 68/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0140
# Epoch 69/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0145
# Epoch 70/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0095 - val_loss: 0.0138
# Epoch 71/100
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 0.0139
# Epoch 72/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0131
# Epoch 73/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0095 - val_loss: 0.0137
# Epoch 74/100
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0094 - val_loss: 0.0141
# Epoch 75/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0144
# Epoch 76/100
# 70/70 [==============================] - 0s 2ms/step - loss: 0.0094 - val_loss: 0.0145
# Epoch 77/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0094 - val_loss: 0.0137
# Epoch 78/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0141
# Epoch 79/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0138
# Epoch 80/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0136
# Epoch 81/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0144
# Epoch 82/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0139
# Epoch 83/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0141
# Epoch 84/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0131
# Epoch 85/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0137
# Epoch 86/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0093 - val_loss: 0.0138
# Epoch 87/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0136
# Epoch 88/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0093 - val_loss: 0.0147
# Epoch 89/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0092 - val_loss: 0.0134
# Epoch 90/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0139
# Epoch 91/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0093 - val_loss: 0.0138
# Epoch 92/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0137
# Epoch 93/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0137
# Epoch 94/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0094 - val_loss: 0.0151
# Epoch 95/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0142
# Epoch 96/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0134
# Epoch 97/100
# 70/70 [==============================] - 0s 4ms/step - loss: 0.0093 - val_loss: 0.0140
# Epoch 98/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0140
# Epoch 99/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 0.0146
# Epoch 100/100
# 70/70 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0131

# %%
from sklearn.metrics import mean_squared_error
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# # invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform(trainY.reshape(-1,1))
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform(testY.reshape(-1,1))

# %%
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
